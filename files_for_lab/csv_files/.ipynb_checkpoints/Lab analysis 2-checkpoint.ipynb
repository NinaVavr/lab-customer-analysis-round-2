# %% [markdown]
# # Round2

# %%
#!pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
#Show the dataframe shape.
file1 = pd.read_csv('marketing_customer_analysis.csv')
display(file1.head())
file1.shape
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#Standardize header names as lower
cols1 = []
for column in file1.columns:
    cols1.append(column.lower())
cols1
file1.columns = cols1

file1.head()

file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
#Numerical columns
num_cols = file1._get_numeric_data()
num_cols
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
#Categorical columns
file1.select_dtypes(exclude='number')
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
#Creating a table to show the percentage of NaN values/column
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                      unnamed: 0           0.00
# 1                        customer           0.00
# 2                           state           5.78
# 3         customer lifetime value           0.00
# 4                        response           5.78
# 5                        coverage           0.00
# 6                       education           0.00
# 7               effective to date           0.00
# 8                employmentstatus           0.00
# 9                          gender           0.00
# 10                         income           0.00
# 11                  location code           0.00
# 12                 marital status           0.00
# 13           monthly premium auto           0.00
# 14        months since last claim           5.80
# 15  months since policy inception           0.00
# 16      number of open complaints           5.80
# 17             number of policies           0.00
# ...

# %%
#Columns that include NaN values
columns_drop = nulls_df[nulls_df['percent_nulls']>1]['header_name']  
print(columns_drop.values)
# Out:
# ['state' 'response' 'months since last claim' 'number of open complaints'
#  'vehicle class' 'vehicle size' 'vehicle type']

# %%
display(file1)
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1['response'].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64

# %%
#Replacing NaN value at ' response' column by 'Do not know'
file1['response']=file1['response'].fillna('Do not know')

# %%
file1['state'].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
#Replacing NaN value at 'state' column by the most common state.
file1['state']=file1['state'].fillna('California')

# %%
file1['months since last claim'].value_counts(dropna=False)
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
#Replacing NaN value by the most common month.
file1['months since last claim']=file1['months since last claim'].fillna('3.0')

# %%
file1['number of open complaints'].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
#Replacing NaN value by the most common number.
file1['number of open complaints']=file1['number of open complaints'].fillna('0.0')

# %%
file1['vehicle class'].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
#Replacing NaN value by the most common vehicle class.
file1['vehicle class']=file1['vehicle class'].fillna('Four-Door Car')

# %%
file1['vehicle size'].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle size, dtype: int64

# %%
#Replacing NaN value by the most common vehicle size.
file1['vehicle size']=file1['vehicle size'].fillna('Medsize')

# %%
file1['vehicle type'].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: vehicle type, dtype: int64

# %%
#Replacing NaN value by an other type.
file1['vehicle type']=file1['vehicle type'].fillna('B')

# %%
#Setting column 'effective to date' as datetime type
file1['effective to date'] = pd.to_datetime(file1['effective to date'])
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value     response  \
# 0               0  DK49336     Arizona              4809.216960           No
# 1               1  KX64629  California              2228.525238           No
# 2               2  LZ68649  Washington             14947.917300           No
# 3               3  XL78013      Oregon             22332.439460          Yes
# 4               4  QA50777      Oregon              9025.067525           No
# ...           ...      ...         ...                      ...          ...
# 10905       10905  FE99816      Nevada             15563.369440           No
# 10906       10906  KX53892      Oregon              5259.444853           No
# 10907       10907  TL39050     Arizona             23893.304100           No
# 10908       10908  WA60547  California             11971.977650           No
# 10909       10909  IV32877  California              6857.519928  Do not know
#
# ...

# %%
file1['effective to date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective to date, Length: 10910, dtype: datetime64[ns]

# %%
#Insert 'month' column depending on the dates 
file1 ['month'] = file1['effective to date'].dt.month
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value     response  \
# 0               0  DK49336     Arizona              4809.216960           No
# 1               1  KX64629  California              2228.525238           No
# 2               2  LZ68649  Washington             14947.917300           No
# 3               3  XL78013      Oregon             22332.439460          Yes
# 4               4  QA50777      Oregon              9025.067525           No
# ...           ...      ...         ...                      ...          ...
# 10905       10905  FE99816      Nevada             15563.369440           No
# 10906       10906  KX53892      Oregon              5259.444853           No
# 10907       10907  TL39050     Arizona             23893.304100           No
# 10908       10908  WA60547  California             11971.977650           No
# 10909       10909  IV32877  California              6857.519928  Do not know
#
# ...

# %%
#Filtering the data to show the dates from Q1
file2 = file1[file1['month']<4]
file2
# Out:
#        unnamed: 0 customer       state  customer lifetime value     response  \
# 0               0  DK49336     Arizona              4809.216960           No
# 1               1  KX64629  California              2228.525238           No
# 2               2  LZ68649  Washington             14947.917300           No
# 3               3  XL78013      Oregon             22332.439460          Yes
# 4               4  QA50777      Oregon              9025.067525           No
# ...           ...      ...         ...                      ...          ...
# 10905       10905  FE99816      Nevada             15563.369440           No
# 10906       10906  KX53892      Oregon              5259.444853           No
# 10907       10907  TL39050     Arizona             23893.304100           No
# 10908       10908  WA60547  California             11971.977650           No
# 10909       10909  IV32877  California              6857.519928  Do not know
#
# ...

# %% [markdown]
# # #Bonus

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
def change_to_lowercase(word):
    cols1 = []
    for column in file1.columns:
        cols1.append(column.lower())
        cols1
    file1.columns = cols1
    return cols1

file1.head()

file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
def NaN_to_Do_not_know(word):
    item = []
    for item in file1['response']:
        item.replace(' ', 'Do not know')
        item
    file1['response'].value_counts(dropna=False)   
    file1['response'] = item
print(file1['response'])
# Out:
# 0         No
# 1         No
# 2         No
# 3        Yes
# 4         No
#         ...
# 10905     No
# 10906     No
# 10907     No
# 10908     No
# 10909    NaN
# Name: response, Length: 10910, dtype: object

# %% [markdown]
# # ROUND 3

# %%
#show info
file2.dtypes
# Out:
# unnamed: 0                                int64
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                  object
# months since policy inception             int64
# number of open complaints                object
# number of policies                        int64
# policy type                              object
# policy                                   object
# ...

# %%
#Describe DataFrame
file2.describe(include='all').T
# Out:
# C:\Users\ninav\AppData\Local\Temp\ipykernel_38428\3613191499.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   file2.describe(include='all').T
#                                  count unique                  top    freq  \
# unnamed: 0                     10910.0    NaN                  NaN     NaN
# customer                         10910   9134              ID89933       7
# state                            10910      5           California    4183
# customer lifetime value        10910.0    NaN                  NaN     NaN
# response                         10910      3                   No    8813
# coverage                         10910      3                Basic    6660
# education                        10910      5             Bachelor    3272
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Show a plot of the total number of responses.
sns.displot(file2['response'])
plt.show()

# %%
#Show a plot of the response rate by the sales channel.
sns.scatterplot(x=file2['response'], y=file2['sales channel'])
plt.show()

# %%
#Show a plot of the response rate by the total claim amount.
sns.barplot(x="response", y="total claim amount", data=file2)
plt.show()

# %%
#Show a plot of the response rate by income.
sns.boxplot(x = 'response',y='income', data=file2)
plt.show()

# %% [markdown]
# # Round 4

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')
display(file1.head())
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#Check the types of the variables 
file1.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
#Deleting column 'Unnamed: 0' as it has no impact to data
file4= file1.drop(['Unnamed: 0'], axis=1)

# %%
#Get the numeric data into dataframe called numerical 
num_cols4 = file4._get_numeric_data()
num_cols4
numerical = pd.DataFrame(num_cols4)
numerical
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
#I created this list because I wanted to create a loop for distribution plots to look like a normal distribution, but I couldn't figure out how
#plots = list(num_cols4.columns.values)
#plots

# %%
#Getting the categorical columns in a dataframe called categoricals
categ_cols4 = file4.select_dtypes([np.object])
categ_cols4.head()
categorical = pd.DataFrame(categ_cols4)
categorical
# Out:
# C:\Users\ninav\AppData\Local\Temp\ipykernel_1364\3859330883.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categ_cols4 = file4.select_dtypes([np.object])
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# ...

# %%
#Creating distribution plots for the numerical variables
for feature in numerical:
    sns.displot(data=file4, x=feature, height=4, aspect=2, color='orange')

# %%
#Construct histograms
hist = numerical.hist(bins=40)

# %%
#Doing the distributions for different numerical variables look like a normal distribution. In this part I wanted to create a loop for all teh plots
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0

Income_log = file4['Income'].apply(log_transfom_clean1)
sns.displot(Income_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0

Number_of_Policies_log = file4['Number of Policies'].apply(log_transfom_clean1)
sns.displot(Number_of_Policies_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0

Cust_log = file4['Customer Lifetime Value'].apply(log_transfom_clean1)
sns.displot(Cust_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0

N_open_comp_log = file4['Number of Open Complaints'].apply(log_transfom_clean1)
sns.displot(N_open_comp_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0

total_claim_am_log = file4['Total Claim Amount'].apply(log_transfom_clean1)
sns.displot(total_claim_am_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0
    
months_policy_log = file4['Months Since Policy Inception'].apply(log_transfom_clean1)
sns.displot(months_policy_log)
plt.show()

# %%
def log_transfom_clean1(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0
    
months_claim_log = file4['Months Since Last Claim'].apply(log_transfom_clean1)
sns.displot(months_claim_log)
plt.show()

# %%
# Normalizing and scaling ()
# going back to oiginal data
numerical
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
numerical.corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.028306
# Income                                        0.028306  1.000000
# Monthly Premium Auto                          0.403069 -0.009788
# Months Since Last Claim                       0.016052 -0.023814
# Months Since Policy Inception                 0.016960 -0.005903
# Number of Open Complaints                    -0.032243  0.007163
# Number of Policies                            0.016024 -0.009960
# Total Claim Amount                            0.232626 -0.354141
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.403069                 0.016052
# Income                                    -0.009788                -0.023814
# Monthly Premium Auto                       1.000000                 0.008744
# ...

# %%
numerical.describe().T
# Out:
#                                  count          mean           std  \
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
plt.boxplot(numerical['Total Claim Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x217c913da50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x217c913df90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x217c913d7b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x217c913e4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x217c913e770>],
#  'means': []}

# %%
# apply linear regression
lm = linear_model.LinearRegression()

# %%
#chosing Total Claim Amount as the target variable 
y = file4['Income']
X = file4[['Total Claim Amount']]

# %%
regression_line = lm.intercept_ + lm.coef_[0]*file4['Total Claim Amount']
plt.plot(file4['Total Claim Amount'], regression_line, c = 'orange')
sns.scatterplot(x='Total Claim Amount',y='Income',data=file4)
plt.show()

# %%
#code for both the correlation matrix and for seaborn heatmap
correlations_matrix = numerical.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# # Round5

# %%
# Split X- y
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler

y = numerical['Total Claim Amount']
X_num = numerical

# %%
X_num
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
# Normalizing data: make data range from 0 - 1, instead of from min to max
transformer = MinMaxScaler().fit(X_num)
x_normalized = transformer.transform(X_num)
print(x_normalized.shape)
x_normalized
pd.DataFrame(x_normalized, columns=X_num.columns)
# Out:
# (10910, 8)
#        Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                     0.035752  0.480381              0.000000
# 1                     0.004059  0.000000              0.012658
# 2                     0.160264  0.221432              0.164557
# 3                     0.250953  0.490873              0.151899
# 4                     0.087527  0.236795              0.236287
# ...                        ...       ...                   ...
# 10905                 0.167823  0.000000              0.810127
# 10906                 0.041281  0.611576              0.016878
# 10907                 0.270122  0.398446              0.590717
# 10908                 0.123717  0.642072              0.409283
# 10909                 0.060907  0.000000              0.168776
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                     0.200000                       0.525253
# 1                     0.085714                       0.262626
# ...

# %%
pd.DataFrame(x_normalized, columns=X_num.columns).corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.028306
# Income                                        0.028306  1.000000
# Monthly Premium Auto                          0.403069 -0.009788
# Months Since Last Claim                       0.016052 -0.023814
# Months Since Policy Inception                 0.016960 -0.005903
# Number of Open Complaints                    -0.032243  0.007163
# Number of Policies                            0.016024 -0.009960
# Total Claim Amount                            0.232626 -0.354141
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.403069                 0.016052
# Income                                    -0.009788                -0.023814
# Monthly Premium Auto                       1.000000                 0.008744
# ...

# %% [markdown]
# #
